# %%
import pandas as pd

# %%
train_df = pd.read_csv('train.csv')

# %%
train_df.head(5)
# Out:
#                             customer_id              Name  age gender  \
# 0      fffe4300490044003600300030003800   Pattie Morrisey   18      F
# 1  fffe43004900440032003100300035003700       Traci Peery   32      F
# 2      fffe4300490044003100390032003600   Merideth Mcmeen   44      F
# 3  fffe43004900440036003000330031003600  Eufemia Cardwell   37      M
# 4  fffe43004900440031003900350030003600      Meghan Kosak   31      F
#
#   security_no region_category  membership_category joining_date  \
# 0     XW0DQ7H         Village  Platinum Membership   2017-08-17
# 1     5K0N3X1            City   Premium Membership   2017-08-28
# 2     1F2TCL3            Town        No Membership   2016-11-11
# 3     VJGJ33N            City        No Membership   2016-10-29
# 4     SVZXCWB            City        No Membership   2017-09-12
#
#   joined_through_referral referral_id  ... avg_time_spent  \
# 0                      No    xxxxxxxx  ...         300.63
# ...

# %%
test_df = pd.read_csv('test.csv')

# %%
test_df.head()
# Out:
#                             customer_id              Name  age gender  \
# 0  fffe43004900440031003700300030003400    Alethia Meints   50      F
# 1  fffe43004900440031003900370037003300        Ming Lopez   41      M
# 2  fffe43004900440034003800360037003000  Carina Flannigan   31      F
# 3  fffe43004900440036003200370033003400      Kyung Wanner   64      M
# 4  fffe43004900440035003000370031003900       Enola Gatto   16      F
#
#   security_no region_category membership_category joining_date  \
# 0     OQJ1XAY         Village  Premium Membership   2015-11-02
# 1     OUQRPKO         Village     Gold Membership   2016-03-01
# 2     02J2RE7            Town   Silver Membership   2017-03-03
# 3     5YEQIF1            Town   Silver Membership   2017-08-18
# 4     100RYB5            Town       No Membership   2015-05-05
#
#   joined_through_referral referral_id  ... days_since_last_login  \
# 0                      No    xxxxxxxx  ...                    12
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
corr_train = train_df.corr()
corr_train.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_17d84_row0_col0,#T_17d84_row1_col1,#T_17d84_row2_col2,#T_17d84_row3_col3,#T_17d84_row4_col4,#T_17d84_row5_col5{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_17d84_row0_col1,#T_17d84_row2_col0,#T_17d84_row2_col1,#T_17d84_row4_col0,#T_17d84_row5_col0{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_17d84_row0_col2,#T_17d84_row4_col2{
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }#T_17d84_row0_col3,#T_17d84_row0_col5{
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }#T_17d84_row0_col4,#T_17d84_row2_col4,#T_17d84_row2_col5{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_17d84_row1_col0,#T_17d84_row3_col0,#T_17d84_row3_col5,#T_17d84_row5_col1,#T_17d84_row5_col2,#T_17d84_row5_col3,#T_17d84_row5_col4{
#             background-color:  #fff7fb;
# ...

# %%
corr_test = test_df.corr()
corr_test.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_083bf_row0_col0,#T_083bf_row1_col1,#T_083bf_row2_col2,#T_083bf_row3_col3,#T_083bf_row4_col4{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_083bf_row0_col1{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_083bf_row0_col2,#T_083bf_row3_col1{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_083bf_row0_col3,#T_083bf_row1_col2,#T_083bf_row1_col3,#T_083bf_row1_col4,#T_083bf_row2_col0,#T_083bf_row2_col1,#T_083bf_row3_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_083bf_row0_col4,#T_083bf_row2_col3,#T_083bf_row4_col0,#T_083bf_row4_col1{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_083bf_row1_col0{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_083bf_row2_col4{
#             background-color:  #3c4ec2;
# ...

# %%
train_df.isnull().sum()
# Out:
# customer_id                        0
# Name                               0
# age                                0
# gender                             0
# security_no                        0
# region_category                 5428
# membership_category                0
# joining_date                       0
# joined_through_referral            0
# referral_id                        0
# preferred_offer_types            288
# medium_of_operation                0
# internet_option                    0
# last_visit_time                    0
# days_since_last_login              0
# avg_time_spent                     0
# avg_transaction_value              0
# avg_frequency_login_days           0
# points_in_wallet                3443
# used_special_discount              0
# offer_application_preference       0
# past_complaint                     0
# complaint_status                   0
# feedback                           0
# churn_risk_score                   0
# dtype: int64

# %%
region = train_df.groupby('region_category')

# %%
region.head()
# Out:
#                              customer_id              Name  age gender  \
# 0       fffe4300490044003600300030003800   Pattie Morrisey   18      F
# 1   fffe43004900440032003100300035003700       Traci Peery   32      F
# 2       fffe4300490044003100390032003600   Merideth Mcmeen   44      F
# 3   fffe43004900440036003000330031003600  Eufemia Cardwell   37      M
# 4   fffe43004900440031003900350030003600      Meghan Kosak   31      F
# 5   fffe43004900440036003300320035003300    Leslie Browder   13      M
# 6   fffe43004900440031003100360037003900     Bridget Balog   21      M
# 7       fffe4300490044003800300035003800    Herma Torgeson   42      M
# 8   fffe43004900440033003300330032003200    Pattie Helmers   44      M
# 9   fffe43004900440032003000340038003300    Shaquana Leech   45      F
# 10  fffe43004900440035003200390031003400     Mariana Hakes   25      F
# 11      fffe4300490044003500380036003900     Polly Medders   60      M
# ...

# %%
train_df.fillna(train_df.mean(), inplace=True)

# %%
train_df
# Out:
#                                 customer_id              Name  age gender  \
# 0          fffe4300490044003600300030003800   Pattie Morrisey   18      F
# 1      fffe43004900440032003100300035003700       Traci Peery   32      F
# 2          fffe4300490044003100390032003600   Merideth Mcmeen   44      F
# 3      fffe43004900440036003000330031003600  Eufemia Cardwell   37      M
# 4      fffe43004900440031003900350030003600      Meghan Kosak   31      F
# ...                                     ...               ...  ...    ...
# 36987  fffe43004900440035003500390036003100          Cuc Tarr   46      F
# 36988  fffe43004900440033003500380036003600    Jenni Stronach   29      F
# 36989      fffe4300490044003500330034003100     Luciana Kinch   23      F
# 36990  fffe43004900440031003200390039003000     Tawana Ardoin   53      M
# 36991  fffe43004900440033003600340034003200  Verlene Beaulieu   35      M
#
#       security_no region_category  membership_category joining_date  \
# ...

# %%
train_df.isnull().sum()
# Out:
# customer_id                        0
# Name                               0
# age                                0
# gender                             0
# security_no                        0
# region_category                 5428
# membership_category                0
# joining_date                       0
# joined_through_referral            0
# referral_id                        0
# preferred_offer_types            288
# medium_of_operation                0
# internet_option                    0
# last_visit_time                    0
# days_since_last_login              0
# avg_time_spent                     0
# avg_transaction_value              0
# avg_frequency_login_days           0
# points_in_wallet                   0
# used_special_discount              0
# offer_application_preference       0
# past_complaint                     0
# complaint_status                   0
# feedback                           0
# churn_risk_score                   0
# dtype: int64

# %%
train_df['preferred_offer_types'].head()
# Out:
# 0       Gift Vouchers/Coupons
# 1       Gift Vouchers/Coupons
# 2       Gift Vouchers/Coupons
# 3       Gift Vouchers/Coupons
# 4    Credit/Debit Card Offers
# Name: preferred_offer_types, dtype: object

# %%
train_df
# Out:
#                                 customer_id              Name  age gender  \
# 0          fffe4300490044003600300030003800   Pattie Morrisey   18      F
# 1      fffe43004900440032003100300035003700       Traci Peery   32      F
# 2          fffe4300490044003100390032003600   Merideth Mcmeen   44      F
# 3      fffe43004900440036003000330031003600  Eufemia Cardwell   37      M
# 4      fffe43004900440031003900350030003600      Meghan Kosak   31      F
# ...                                     ...               ...  ...    ...
# 36987  fffe43004900440035003500390036003100          Cuc Tarr   46      F
# 36988  fffe43004900440033003500380036003600    Jenni Stronach   29      F
# 36989      fffe4300490044003500330034003100     Luciana Kinch   23      F
# 36990  fffe43004900440031003200390039003000     Tawana Ardoin   53      M
# 36991  fffe43004900440033003600340034003200  Verlene Beaulieu   35      M
#
#       security_no region_category  membership_category joining_date  \
# ...

# %%
train_df.shape
# Out:
# (36992, 25)

# %%
train_df=train_df.dropna()

# %%
train_df.isnull().sum()
# Out:
# customer_id                     0
# Name                            0
# age                             0
# gender                          0
# security_no                     0
# region_category                 0
# membership_category             0
# joining_date                    0
# joined_through_referral         0
# referral_id                     0
# preferred_offer_types           0
# medium_of_operation             0
# internet_option                 0
# last_visit_time                 0
# days_since_last_login           0
# avg_time_spent                  0
# avg_transaction_value           0
# avg_frequency_login_days        0
# points_in_wallet                0
# used_special_discount           0
# offer_application_preference    0
# past_complaint                  0
# complaint_status                0
# feedback                        0
# churn_risk_score                0
# dtype: int64

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31325 entries, 0 to 36991
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   customer_id                   31325 non-null  object
#  1   Name                          31325 non-null  object
#  2   age                           31325 non-null  int64
#  3   gender                        31325 non-null  object
#  4   security_no                   31325 non-null  object
#  5   region_category               31325 non-null  object
#  6   membership_category           31325 non-null  object
#  7   joining_date                  31325 non-null  object
#  8   joined_through_referral       31325 non-null  object
#  9   referral_id                   31325 non-null  object
#  10  preferred_offer_types         31325 non-null  object
#  11  medium_of_operation           31325 non-null  object
# ...

# %%
train_df.head()
# Out:
#                             customer_id              Name  age gender  \
# 0      fffe4300490044003600300030003800   Pattie Morrisey   18      F
# 1  fffe43004900440032003100300035003700       Traci Peery   32      F
# 2      fffe4300490044003100390032003600   Merideth Mcmeen   44      F
# 3  fffe43004900440036003000330031003600  Eufemia Cardwell   37      M
# 4  fffe43004900440031003900350030003600      Meghan Kosak   31      F
#
#   security_no region_category  membership_category joining_date  \
# 0     XW0DQ7H         Village  Platinum Membership   2017-08-17
# 1     5K0N3X1            City   Premium Membership   2017-08-28
# 2     1F2TCL3            Town        No Membership   2016-11-11
# 3     VJGJ33N            City        No Membership   2016-10-29
# 4     SVZXCWB            City        No Membership   2017-09-12
#
#   joined_through_referral referral_id  ... avg_time_spent  \
# 0                      No    xxxxxxxx  ...         300.63
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaling_column = ['avg_time_spent', 'avg_transaction_value', 'points_in_wallet', 'age']
train_df[scaling_column] = scaler.fit_transform(train_df[scaling_column])
# Out:
# <ipython-input-24-92b7c80c5b72>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[scaling_column] = scaler.fit_transform(train_df[scaling_column])
# C:\Users\andhika\anaconda3\envs\gputest\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)

# %%
print(train_df[scaling_column].describe().T[['min','max']])
# Out:
#                        min  max
# avg_time_spent         0.0  1.0
# avg_transaction_value  0.0  1.0
# points_in_wallet       0.0  1.0
# age                    0.0  1.0

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
LE = LabelEncoder()

# %%
train_df['region_category'] = LE.fit_transform(train_df['region_category'])
print(LE.classes_)
print(np.sort(train_df['region_category'].unique()))
test_df['region_category'] = LE.fit_transform(test_df['region_category'])
print(LE.classes_)
print(np.sort(test_df['region_category'].unique()))
# Out:
# ['City' 'Town' 'Village']
# [0 1 2]
# ['City' 'Town' 'Village' nan]
# [0 1 2 3]
# <ipython-input-28-f9349ae2d5ab>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['region_category'] = LE.fit_transform(train_df['region_category'])

# %%
train_df['membership_category'] = LE.fit_transform(train_df['membership_category'])
print(LE.classes_)
print(np.sort(train_df['membership_category'].unique()))
test_df['membership_category'] = LE.fit_transform(test_df['membership_category'])
print(LE.classes_)
print(np.sort(test_df['membership_category'].unique()))
# Out:
# ['Basic Membership' 'Gold Membership' 'No Membership'
#  'Platinum Membership' 'Premium Membership' 'Silver Membership']
# [0 1 2 3 4 5]
# ['Basic Membership' 'Gold Membership' 'No Membership'
#  'Platinum Membership' 'Premium Membership' 'Silver Membership']
# [0 1 2 3 4 5]
# <ipython-input-29-290b67201cbd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['membership_category'] = LE.fit_transform(train_df['membership_category'])

# %%
train_df['joined_through_referral'] = LE.fit_transform(train_df['joined_through_referral'])
print(LE.classes_)
print(np.sort(train_df['joined_through_referral'].unique()))
test_df['joined_through_referral'] = LE.fit_transform(test_df['joined_through_referral'])
print(LE.classes_)
print(np.sort(test_df['joined_through_referral'].unique()))
# Out:
# ['?' 'No' 'Yes']
# [0 1 2]
# ['?' 'No' 'Yes']
# [0 1 2]
# <ipython-input-30-f29aa7e8841c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['joined_through_referral'] = LE.fit_transform(train_df['joined_through_referral'])

# %%
train_df['avg_frequency_login_days'] = LE.fit_transform(train_df['avg_frequency_login_days'])
print(LE.classes_)
print(np.sort(train_df['avg_frequency_login_days'].unique()))
test_df['avg_frequency_login_days'] = LE.fit_transform(test_df['avg_frequency_login_days'])
print(LE.classes_)
print(np.sort(test_df['avg_frequency_login_days'].unique()))
# Out:
# ['-0.006221399295291974' '-0.04739266802603481' '-0.09174297529623487' ...
#  '8.0' '9.0' 'Error']
# [   0    1    2 ... 1389 1390 1391]
# ['-0.026667545779886836' '-0.06942939967747463' '-0.07190318101047666'
#  '-0.273327911179404' '-0.29918939974785985' '-0.3908663392482268'
#  '-0.4233593837231098' '-0.5161083168648197' '-0.5804374915495742'
#  '-0.6239989916117423' '-0.6484950853201994' '-0.661004556843551'
#  '-0.718868518155233' '-0.9458767849665399' '-1.0353764418504916'
#  '-1.0399072695776468' '-1.127860427894607' '-1.1305249835473674'
#  '-1.3079733783962908' '-1.3375387749219776' '-1.349075024214578'
#  '-1.440407084693085' '-1.479436947311175' '-1.570049566433866'
#  '-1.6320631276187711' '-1.6882231585671263' '-1.8040004091573394'
#  '-1.8363686235116141' '-1.9603253977031159' '-10.189996924972949'
#  '-10.217711541397001' '-10.295850884362075' '-10.392687598903422'
#  '-10.449115267983899' '-10.454395363171955' '-10.507851530769585'
# ...

# %%
train_df['offer_application_preference'] = LE.fit_transform(train_df['offer_application_preference'])
print(LE.classes_)
print(np.sort(train_df['offer_application_preference'].unique()))

test_df['offer_application_preference'] = LE.fit_transform(test_df['offer_application_preference'])
print(LE.classes_)
print(np.sort(test_df['offer_application_preference'].unique()))
# Out:
# ['No' 'Yes']
# [0 1]
# ['No' 'Yes']
# [0 1]
# <ipython-input-32-162292fcdf34>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['offer_application_preference'] = LE.fit_transform(train_df['offer_application_preference'])

# %%
train_df['used_special_discount'] = LE.fit_transform(train_df['used_special_discount'])
print(LE.classes_)
print(np.sort(train_df['used_special_discount'].unique()))

test_df['used_special_discount'] = LE.fit_transform(test_df['used_special_discount'])
print(LE.classes_)
print(np.sort(test_df['used_special_discount'].unique()))
# Out:
# <ipython-input-33-4dcc0d3852ce>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['used_special_discount'] = LE.fit_transform(train_df['used_special_discount'])
# ['No' 'Yes']
# [0 1]
# ['No' 'Yes']
# [0 1]

# %%
train_df['past_complaint'] = LE.fit_transform(train_df['past_complaint'])
print(LE.classes_)
print(np.sort(train_df['past_complaint'].unique()))

test_df['past_complaint'] = LE.fit_transform(test_df['past_complaint'])
print(LE.classes_)
print(np.sort(test_df['past_complaint'].unique()))
# Out:
# ['No' 'Yes']
# [0 1]
# ['No' 'Yes']
# [0 1]
# <ipython-input-34-1f164355bdfe>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['past_complaint'] = LE.fit_transform(train_df['past_complaint'])

# %%
train_df['complaint_status'] = LE.fit_transform(train_df['complaint_status'])
print(LE.classes_)
print(np.sort(train_df['complaint_status'].unique()))

test_df['complaint_status'] = LE.fit_transform(test_df['complaint_status'])
print(LE.classes_)
print(np.sort(test_df['complaint_status'].unique()))
# Out:
# ['No Information Available' 'Not Applicable' 'Solved'
#  'Solved in Follow-up' 'Unsolved']
# [0 1 2 3 4]
# ['No Information Available' 'Not Applicable' 'Solved'
#  'Solved in Follow-up' 'Unsolved']
# [0 1 2 3 4]
# <ipython-input-35-5a625c7c0d65>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['complaint_status'] = LE.fit_transform(train_df['complaint_status'])

# %%
train_df['feedback'] = LE.fit_transform(train_df['feedback'])
print(LE.classes_)
print(np.sort(train_df['feedback'].unique()))

test_df['feedback'] = LE.fit_transform(test_df['feedback'])
print(LE.classes_)
print(np.sort(test_df['feedback'].unique()))
# Out:
# ['No reason specified' 'Poor Customer Service' 'Poor Product Quality'
#  'Poor Website' 'Products always in Stock' 'Quality Customer Care'
#  'Reasonable Price' 'Too many ads' 'User Friendly Website']
# [0 1 2 3 4 5 6 7 8]
# <ipython-input-36-c99756fe8011>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['feedback'] = LE.fit_transform(train_df['feedback'])
# ['No reason specified' 'Poor Customer Service' 'Poor Product Quality'
#  'Poor Website' 'Products always in Stock' 'Quality Customer Care'
#  'Reasonable Price' 'Too many ads' 'User Friendly Website']
# [0 1 2 3 4 5 6 7 8]

# %%
train_df['gender'] = LE.fit_transform(train_df['gender'])
print(LE.classes_)
print(np.sort(train_df['gender'].unique()))

test_df['gender'] = LE.fit_transform(test_df['gender'])
print(LE.classes_)
print(np.sort(test_df['gender'].unique()))
# Out:
# ['F' 'M' 'Unknown']
# [0 1 2]
# ['F' 'M' 'Unknown']
# [0 1 2]
# <ipython-input-37-25ff7211954a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['gender'] = LE.fit_transform(train_df['gender'])

# %%
train_df['joining_date'] = pd.to_datetime(train_df['joining_date'])
test_df['joining_date'] = pd.to_datetime(test_df['joining_date'])
# Out:
# <ipython-input-38-88b5c62096f2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['joining_date'] = pd.to_datetime(train_df['joining_date'])

# %%
features = ["age","region_category", "membership_category", "joined_through_referral", "avg_time_spent", "avg_transaction_value", "points_in_wallet", "used_special_discount", "offer_application_preference", "past_complaint", "complaint_status", "feedback","days_since_last_login","avg_frequency_login_days","gender"]

# %%
y = train_df["churn_risk_score"]

# %%
X = train_df[features]
X_test = test_df[features]

# %%
security_no_group_count = test_df.groupby('internet_option')
security_no_group_count['internet_option'].count()
# Out:
# internet_option
# Fiber_Optic    6747
# Mobile_Data    6573
# Wi-Fi          6599
# Name: internet_option, dtype: int64

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
test_df.isnull().sum()
# Out:
# customer_id                        0
# Name                               0
# age                                0
# gender                             0
# security_no                        0
# region_category                    0
# membership_category                0
# joining_date                       0
# joined_through_referral            0
# referral_id                        0
# preferred_offer_types            159
# medium_of_operation                0
# internet_option                    0
# last_visit_time                    0
# days_since_last_login              0
# avg_time_spent                     0
# avg_transaction_value              0
# avg_frequency_login_days           0
# points_in_wallet                1963
# used_special_discount              0
# offer_application_preference       0
# past_complaint                     0
# complaint_status                   0
# feedback                           0
# dtype: int64

# %%
test_df.fillna(test_df.mean(), inplace=True)
test_df.isnull().sum()
X_test.fillna(X_test.mean(), inplace=True)
# Out:
# <ipython-input-45-9dc29306d389>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   test_df.fillna(test_df.mean(), inplace=True)
# C:\Users\andhika\anaconda3\envs\gputest\lib\site-packages\pandas\core\series.py:4460: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
model = RandomForestRegressor(n_estimators=200, max_depth=5, 
                              random_state=1, criterion="mse", 
                              bootstrap=False, verbose= 100,
                              n_jobs= -1, max_leaf_nodes = 100, warm_start=True, max_features="auto",
                             )
model.fit(X, y)
predictions = np.rint(model.predict(X_test))
predictions
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# building tree 1 of 200
# building tree 2 of 200
# building tree 3 of 200
# building tree 4 of 200
# building tree 5 of 200
# building tree 6 of 200building tree 7 of 200
#
# building tree 8 of 200
# building tree 9 of 200building tree 10 of 200building tree 11 of 200
#
# building tree 12 of 200
#
# building tree 13 of 200[Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.1s
#
# building tree 14 of 200
# building tree 15 of 200
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.1s
# building tree 16 of 200building tree 17 of 200
# building tree 18 of 200
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    0.1s
# building tree 19 of 200
# ...

# %%
output = pd.DataFrame({'customer_id': test_df.customer_id, 'churn_risk_score': predictions})
output.to_csv('submission_2_verbose_gender.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!

# %%
from sklearn.metrics import confusion_matrix, classification_report, f1_score

# %%
y.shape
# Out:
# (31325,)

# %%
predictions.shape
# Out:
# (19919,)

# %%
print('\nClassification report:')
cr = classification_report(y[:19919], predictions)
print(cr)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00       633
#            1       0.06      0.13      0.09      1422
#            2       0.08      0.01      0.02      1513
#            3       0.28      0.23      0.25      5598
#            4       0.27      0.44      0.34      5411
#            5       0.27      0.17      0.21      5342
#
#     accuracy                           0.24     19919
#    macro avg       0.16      0.16      0.15     19919
# weighted avg       0.23      0.24      0.22     19919
# C:\Users\andhika\anaconda3\envs\gputest\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
wadaw = f1_score(y[:19919], predictions, average="macro")

# %%
wadaw_score = 100 * wadaw

# %%
wadaw_score
# Out:
# 15.017619947851665

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
Tree = DecisionTreeRegressor(random_state=1)
Tree.fit(X, y)
pred = np.rint(Tree.predict(X_test))

# %%
wadaw_Tree = f1_score(y[:19919], pred, average="macro")

# %%
score = 100 * wadaw_Tree

# %%
score
# Out:
# 10.869509358941091

# %%
'''
output = pd.DataFrame({'customer_id': test_df.customer_id, 'churn_risk_score': pred})
output.to_csv('submission_Tree.csv', index=False)
print("Your submission was successfully saved!")
'''
# Out:
# '\noutput = pd.DataFrame({\'customer_id\': test_df.customer_id, \'churn_risk_score\': pred})\noutput.to_csv(\'submission_Tree.csv\', index=False)\nprint("Your submission was successfully saved!")\n'

# %%
from sklearn.linear_model import LinearRegression

# %%
LinReg = LinearRegression()
LinReg.fit(X, y)
pred_LinReg = np.rint(LinReg.predict(X_test))

# %%
wadaw_LinReg = f1_score(y[:19919], pred_LinReg, average="macro")

# %%
score = 100 * wadaw_LinReg

# %%
score
# Out:
# 0.0

# %%
pred_LinReg
# Out:
# array([-63439., -17088.,  -8191., ..., -28787., -23220., -59313.])

# %%
from sklearn.linear_model import LogisticRegression

# Call the classifier
logreg = LogisticRegression()
# Fit the classifier to the training data  
logreg = logreg.fit(X, y)
#Training Model: Predict 
y_pred = logreg.predict(X_test)
# Out:
# C:\Users\andhika\anaconda3\envs\gputest\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
wadaw_LogReg = f1_score(y[:19919], y_pred, average="macro")
score = 100 * wadaw_LogReg

# %%
score
# Out:
# 2.3325561560041885

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
'''
output = pd.DataFrame({'customer_id': test_df.customer_id, 'churn_risk_score': y_pred})
output.to_csv('submission_Log.csv', index=False)
print("Your submission was successfully saved!")
'''
# Out:
# '\noutput = pd.DataFrame({\'customer_id\': test_df.customer_id, \'churn_risk_score\': y_pred})\noutput.to_csv(\'submission_Log.csv\', index=False)\nprint("Your submission was successfully saved!")\n'

# %%
corr_train_2 = train_df.corr()

# %%
corr_train_2.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_6da4e_row0_col0,#T_6da4e_row1_col1,#T_6da4e_row2_col2,#T_6da4e_row3_col3,#T_6da4e_row4_col4,#T_6da4e_row5_col5,#T_6da4e_row6_col6,#T_6da4e_row7_col7,#T_6da4e_row8_col8,#T_6da4e_row9_col9,#T_6da4e_row10_col10,#T_6da4e_row11_col11,#T_6da4e_row12_col12,#T_6da4e_row13_col13,#T_6da4e_row14_col14,#T_6da4e_row15_col15{
#             background-color:  #023858;
#             color:  #f1f1f1;
# ...

# %%
corr_test_2 = test_df.corr()
corr_test_2.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_066bb_row0_col0,#T_066bb_row1_col1,#T_066bb_row2_col2,#T_066bb_row3_col3,#T_066bb_row4_col4,#T_066bb_row5_col5,#T_066bb_row6_col6,#T_066bb_row7_col7,#T_066bb_row8_col8,#T_066bb_row9_col9,#T_066bb_row10_col10,#T_066bb_row11_col11,#T_066bb_row12_col12,#T_066bb_row13_col13,#T_066bb_row14_col14{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_066bb_row0_col1,#T_066bb_row1_col5,#T_066bb_row1_col13,#T_066bb_row2_col1,#T_066bb_row2_col13,#T_066bb_row5_col1,#T_066bb_row5_col13,#T_066bb_row6_col3,#T_066bb_row7_col5,#T_066bb_row7_col12,#T_066bb_row8_col0,#T_066bb_row9_col1,#T_066bb_row9_col5,#T_066bb_row9_col13,#T_066bb_row10_col2,#T_066bb_row10_col13,#T_066bb_row11_col9,#T_066bb_row12_col8,#T_066bb_row13_col8,#T_066bb_row13_col9,#T_066bb_row14_col12{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
# ...

# %%
train_df["last_visit_time"]
# Out:
# 0        16:08:02
# 1        12:38:13
# 2        22:53:21
# 3        15:57:50
# 4        15:46:44
#            ...
# 36985    03:30:17
# 36986    05:29:19
# 36988    23:18:31
# 36990    09:50:03
# 36991    01:39:52
# Name: last_visit_time, Length: 31325, dtype: object

# %%
train_df["days_since_last_login"]
# Out:
# 0        17
# 1        16
# 2        14
# 3        11
# 4        20
#          ..
# 36985    13
# 36986    13
# 36988    13
# 36990    15
# 36991    15
# Name: days_since_last_login, Length: 31325, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.relplot(y[:19919], predictions)
plt.ylim(ymin=0)
plt.xlim(xmin=0)
# Out:
# C:\Users\andhika\anaconda3\envs\gputest\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (0.0, 5.3)

# %%
sns.countplot(train_df["churn_risk_score"][:19919])
plt.show()
# Out:
# C:\Users\andhika\anaconda3\envs\gputest\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(predictions)
# Out:
# C:\Users\andhika\anaconda3\envs\gputest\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='count'>

# %%
model = RandomForestRegressor(n_estimators=200, max_depth=5, 
                              random_state=1, criterion="mse", 
                              bootstrap=False, verbose= 100,
                              n_jobs= -1, max_leaf_nodes = 100, warm_start=True, max_features="auto",
                             )
model.fit(X, y)
predictions = np.rint(model.predict(X_test))
predictions
cm = confusion_matrix(y[:19919],predictions)
print(cm)
plt.imshow(cm)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# building tree 1 of 200building tree 2 of 200
# building tree 3 of 200
#
# building tree 4 of 200
# building tree 5 of 200building tree 6 of 200
# building tree 7 of 200building tree 8 of 200
#
#
# building tree 9 of 200building tree 10 of 200
#
# building tree 11 of 200
# building tree 12 of 200
# building tree 13 of 200[Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.1s
#
# building tree 14 of 200[Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.1s
#
# building tree 15 of 200
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.1s
# building tree 16 of 200[Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.1s
#
# building tree 17 of 200[Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.1s
#
# building tree 18 of 200[Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    0.1s
#
# ...

# %%
plt.plot(cm)

# %%
from sklearn import neighbors
from sklearn.metrics import mean_squared_error 
from math import sqrt

# %%
rmse_val = [] #to store rmse values for different k
for K in range(20):
    K = K+1
    model = neighbors.KNeighborsRegressor(n_neighbors = K, algorithm='brute')

    model.fit(X, y)  #fit the model
    pred=model.predict(X_test) #make prediction on test set
    error = sqrt(mean_squared_error(y[:19919],pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  1 is: 2.761209576838611
# RMSE value for k=  2 is: 2.549347297871145
# RMSE value for k=  3 is: 2.450413001364964
# RMSE value for k=  4 is: 2.4925147744997327
# RMSE value for k=  5 is: 2.5587222575623456
# RMSE value for k=  6 is: 2.570157053791722
# RMSE value for k=  7 is: 2.5648413072975877
# RMSE value for k=  8 is: 2.554074988845672
# RMSE value for k=  9 is: 2.5480577129963584
# RMSE value for k=  10 is: 2.5420879123990145
# RMSE value for k=  11 is: 2.540446972769751
# RMSE value for k=  12 is: 2.5355364746397826
# RMSE value for k=  13 is: 2.5268550051253587
# RMSE value for k=  14 is: 2.521156679157327
# RMSE value for k=  15 is: 2.5109979264757047
# RMSE value for k=  16 is: 2.4979056834006603
# RMSE value for k=  17 is: 2.478615320593538
# RMSE value for k=  18 is: 2.4576276141623503
# RMSE value for k=  19 is: 2.4397304627765513
# RMSE value for k=  20 is: 2.4235533310681556

# %%
pred = np.rint(pred)

# %%
score = 100 * wadaw_KNN

# %%
score
# Out:
# 0.0

# %%
output = pd.DataFrame({'customer_id': test_df.customer_id, 'churn_risk_score': pred})
output.to_csv('submissionKNN_7.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!

# %%
pred
# Out:
# array([2., 1., 2., ..., 1., 2., 2.])
